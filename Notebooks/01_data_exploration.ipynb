# %%
import pandas as pd

df = pd.read_csv("C:/Users/mxhwt/OneDrive/Desktop/Football_Project/brighton_high_press_analysis/Data/raw/brighton_2025_26_scores_fixtures.csv")
df.head()
# Out:
#          Date   Time            Comp         Round  Day Venue Result  GF  GA  \
# 0  2025-08-16  15:00  Premier League   Matchweek 1  Sat  Home      D   1   1
# 1  2025-08-24  14:00  Premier League   Matchweek 2  Sun  Away      L   0   2
# 2  2025-08-27  19:45         EFL Cup  Second round  Wed  Away      W   6   0
# 3  2025-08-31  14:00  Premier League   Matchweek 3  Sun  Home      W   2   1
# 4  2025-09-13  15:00  Premier League   Matchweek 4  Sat  Away      L   1   2
#
#           Opponent  Poss  Attendance       Captain Formation Opp Formation  \
# 0           Fulham    50       31478    Lewis Dunk   4-2-3-1       4-2-3-1
# 1          Everton    57       51759    Lewis Dunk   4-2-3-1       4-2-3-1
# 2    Oxford United    62        9010  James Milner   4-2-3-1         5-4-1
# 3  Manchester City    37       31485    Lewis Dunk   4-2-3-1         4-3-3
# 4      Bournemouth    48       11167    Lewis Dunk   4-2-3-1       4-2-3-1
#
#            Referee  Match Report  Notes
# ...
